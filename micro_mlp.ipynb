# %%
import micro_mlp as mmlp
import numpy as np
import matplotlib.pyplot as plt
import yaml
import pprint

# %%
cfg = mmlp.LoadANNConfigFile("sine_mlp.yml")
pp = pprint.PrettyPrinter()
pp.pprint(cfg)
# Out:
# {'Layers': [{'InputDim': 1, 'OutputDim': 1, 'name': 'Input'},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 1,
#              'OutputDim': 3,
#              'name': 'Layer1'},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 3,
#              'OutputDim': 3,
#              'name': 'Layer2'},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 3,
#              'OutputDim': 1,
#              'name': 'Output'}],
#  'Network_Name': 'Sine',
#  'Training_Cost': 'Error_Squared',
#  'Training_Method': 'Back_Prop'}
# C:\Users\dominick.hambrick\Projects\micro_mlp\micro_mlp.py:19: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   ann_config = yaml.load(stream)

# %%
cfg = mmlp.InitializeMLP(cfg)

# %%
t = np.linspace(0,np.pi,num=10).reshape(-1,1)
y = np.sin(t)
plt.plot(t,y)

# %%
pp.pprint(cfg)
mmlp.WeightPerturbationTrain(t,y,cfg)
# Out:
# {'Layers': [{'InputDim': 1,
#              'OutputDim': 1,
#              'name': 'Input',
#              'weights': array([[0.20507967]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 1,
#              'OutputDim': 3,
#              'name': 'Layer1',
#              'weights': array([[-0.04290744],
#        [-0.7569044 ],
#        [-0.8070475 ]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 3,
#              'OutputDim': 3,
#              'name': 'Layer2',
#              'weights': array([[ 0.20711265,  0.46162097,  0.62004073],
#        [ 0.19200258, -0.16061628, -0.49515675],
#        [-0.03707005,  0.50817471,  0.15948434]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 3,
#              'OutputDim': 1,
#              'name': 'Output',
#              'weights': array([[-0.45709802, -0.42850931, -0.71565399]])}],
#  'Network_Name': 'Sine',
#  'Training_Cost': 'Error_Squared',
# ...

# %%
vComputeForWardPass = []

# %%
_y = []
for _t in t:
    _y.append(mmlp.ComputeForwardPass(_t,cfg))
# Out:
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# Layer name Layer2
# Input:  (3,)
# Weights (3, 3)
# Layer name Output
# Input:  (3,)
# Weights (1, 3)
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# Layer name Layer2
# Input:  (3,)
# Weights (3, 3)
# Layer name Output
# Input:  (3,)
# Weights (1, 3)
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# Layer name Layer2
# Input:  (3,)
# Weights (3, 3)
# Layer name Output
# Input:  (3,)
# Weights (1, 3)
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# Layer name Layer2
# Input:  (3,)
# Weights (3, 3)
# Layer name Output
# Input:  (3,)
# Weights (1, 3)
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# Layer name Layer2
# Input:  (3,)
# Weights (3, 3)
# Layer name Output
# Input:  (3,)
# Weights (1, 3)
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# Layer name Layer2
# Input:  (3,)
# Weights (3, 3)
# Layer name Output
# Input:  (3,)
# Weights (1, 3)
# Layer name Layer1
# Input:  (1,)
# Weights (3, 1)
# ...

# %%
plt.plot(t,np.asarray(_y))

# %%
xor_cfg = mmlp.LoadANNConfigFile("xor.yml")
pp.pprint(xor_cfg)
# Out:
# {'Layers': [{'InputDim': 2, 'OutputDim': 2, 'name': 'Input'},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 2,
#              'OutputDim': 2,
#              'name': 'Layer1'},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 2,
#              'OutputDim': 1,
#              'name': 'Output'}],
#  'Network_Name': 'XOR',
#  'Training_Cost': 'Error_Squared',
#  'Training_Method': 'Back_Prop'}

# %%
xor_train_x = np.asarray([[0,0],[0,1],[1,0],[1,1]])
xor_train_y = np.asarray([[0],[1],[1],[0]])
print(xor_train_x)
print(xor_train_y)
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# [[0]
#  [1]
#  [1]
#  [0]]

# %%
xor_cfg = mmlp.InitializeMLP(xor_cfg)
pp.pprint(xor_cfg)
# Out:
# {'Layers': [{'InputDim': 2,
#              'OutputDim': 2,
#              'name': 'Input',
#              'weights': array([[ 0.07441409, -0.19306351],
#        [ 0.68320558,  0.44650011]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 2,
#              'OutputDim': 2,
#              'name': 'Layer1',
#              'weights': array([[ 0.94758441, -1.13005805],
#        [ 0.14833469,  0.34271756]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 2,
#              'OutputDim': 1,
#              'name': 'Output',
#              'weights': array([[-0.23932785, -0.90051665]])}],
#  'Network_Name': 'XOR',
#  'Training_Cost': 'Error_Squared',
#  'Training_Method': 'Back_Prop'}

# %%
for t in range(145):
    mmlp.WeightPerturbationTrain(xor_train_x,xor_train_y,xor_cfg)
# Out:
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# MSE:  0.13050500504389678
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# MSE:  0.41859508894389685
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# ...

# %%
_y = []
for _x in xor_train_x:
    _y.append(mmlp.ComputeForwardPass(_x,xor_cfg))
# Out:
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)
# Layer name Layer1
# Input:  (2,)
# Weights (2, 2)
# Layer name Output
# Input:  (2,)
# Weights (1, 2)

# %%
print(_y)
# Out:
# [array([1.]), array([1.]), array([1.]), array([1.])]

# %%
pp.pprint(xor_cfg)
# Out:
# {'Layers': [{'InputDim': 2,
#              'OutputDim': 2,
#              'name': 'Input',
#              'weights': array([[ 0.07441409, -0.19306351],
#        [ 0.68320558,  0.44650011]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 2,
#              'OutputDim': 2,
#              'delta_weights': array([[-0., -0.],
#        [-0., -0.]]),
#              'name': 'Layer1',
#              'weights': array([[ 0.94758441, -1.13438302],
#        [ 0.14833469,  0.32279385]])},
#             {'ActivationFunction': 'sigmoid',
#              'InputDim': 2,
#              'OutputDim': 1,
#              'delta_weights': array([[-0., -0.]]),
#              'name': 'Output',
#              'weights': array([[41.38119337, 40.749844  ]])}],
#  'Network_Name': 'XOR',
#  'Training_Cost': 'Error_Squared',
#  'Training_Method': 'Back_Prop'}
